# %%
#!pip install requests_toolbelt

# %%
import json
import requests
from lxml import html
from time import sleep
import random
from requests_toolbelt.multipart.encoder import MultipartEncoder
import pandas as pd

# %%
url_RUCT = "https://www.educacion.gob.es/ruct/consultaestudios.action"

# %%
response = requests.get(url_RUCT)
root = html.fromstring(response.text)
select_universidades = root.xpath('//select[@id="codigoUniversidad"]')
select_codigoTipo = root.xpath('//select[@id="codigoTipo"]')
options_select_codigoTipo = root.xpath('//select[@id="codigoTipo"]/option')
options_select_universidades = root.xpath('//select[@id="codigoUniversidad"]/option')

list_universidades_ = select_universidades[0].text_content().strip().splitlines()
list_codigoTipo_ = select_codigoTipo[0].text_content().strip().splitlines()

list_universidades_.remove("Todos")
list_codigoTipo_.remove("Todos")

list_universidades = []
for univ in list_universidades_:
    list_universidades.append(univ.strip())
    
list_codigoTipo = []
for codigo in list_codigoTipo_:
    list_codigoTipo.append(codigo.strip())

options_select_codigoTipo.pop(0)
list_options_select_codigoTipo = []
for option in options_select_codigoTipo:
    list_options_select_codigoTipo.append(option.attrib["value"])

options_select_universidades.pop(0)
list_options_select_universidades = []
for option in options_select_universidades:
    list_options_select_universidades.append(option.attrib["value"])

#res = {test_keys[i]: test_values[i] for i in range(len(test_keys))}
dict_universidades = {list_options_select_universidades[i]: list_universidades[i] for i in range(len(list_options_select_universidades))}
dict_codigoTipoTitulacion = {list_options_select_codigoTipo[i]: list_codigoTipo[i] for i in range(len(list_options_select_codigoTipo))}

# %%
columnas_df_RUCT = ["Código", "Título", "Universidad", "Nivel académico", "Estado", "URL"]
df_RUCT = pd.DataFrame(columns = columnas_df_RUCT)

for codigo_universidad, nombre_universidad in dict_universidades.items():
    print("Procesando... " + nombre_universidad)
    for codigoTipoTitulacion, TipoTitulacion in dict_codigoTipoTitulacion.items():
        print("   Procesando " + TipoTitulacion)
        params = {
            "codigoUniversidad": codigo_universidad,
            "codigoTipo": codigoTipoTitulacion,
            'action:listaestudios' : 'clicked',
        }

        data = MultipartEncoder(fields = params)

        headers = {
            'Content-type': data.content_type
        }
        response = requests.post(
            'https://www.educacion.gob.es/ruct/consultaestudios.action?actual=estudios',
            data = data,
            headers = headers
        )
        root2 = html.fromstring(response.text)
        tabla_titulos_ = []
        tabla_titulos_ = root2.xpath('//table[@id="estudio"]')
        if len(tabla_titulos_) > 0 :
            #print("Hay tabla")
            df_table_RUCT = pd.read_html(response.text)
            df_table_RUCT = df_table_RUCT[0]
            df_table_RUCT.rename(columns={'Unnamed: 5': 'URL'}, inplace=True)
            df_table_RUCT["URL"] = "https://www.educacion.gob.es/ruct/estudio.action?codigoCiclo=SC&codigoTipo=G&CodigoEstudio=" + df_table_RUCT["Código"].astype(str) + "&actual=estudios"

            df_RUCT = pd.concat([df_RUCT, df_table_RUCT], ignore_index=True)
            print("      Procesado correctamente.")
        else:
            print("      No hay tabla")
        sleep(random.randint(1,3))
# Out:
# Procesando... Centros autorizados para impartir Enseñanzas Artísticas Superiores
#    Procesando Ciclo
#       No hay tabla
#    Procesando Doctor
#       No hay tabla
#    Procesando Grado
#       No hay tabla
#    Procesando Acreditación Institucional
#       No hay tabla
#    Procesando Máster
#
#    Procesando Ciclo
#       Procesado correctamente.
#    Procesando Doctor
#       Procesado correctamente.
#    Procesando Grado
#       Procesado correctamente.
#    Procesando Acreditación Institucional
#       No hay tabla
#    Procesando Máster
#       Procesado correctamente.
#    Procesando Título Equivalente
#       No hay tabla
#    Procesando Título Extranjero
#       No hay tabla
# Procesando... Universitat Politècnica de València
#    Procesando Ciclo
#       Procesado correctamente.
#    Procesando Doctor
#       Procesado correctamente.
#    Procesando Grado
#       Procesado correctamente.
#    Procesando Acreditación Institucional
#       No hay tabla
#    Procesando Máster
#       Procesado correctamente.
#    Procesando Título Equivalente
#       No hay tabla
#    Procesando Título Extranjero
#       No hay tabla

# %%
display(df_RUCT)
# Out:
#        Código                                             Título  \
# 0     9000164  Título de Conservación y Restauración de Biene...
# 1     9000166                                   Título de Diseño
# 2     9000162                  Título Superior de Arte Dramático
# 3     9000163                        Título Superior de Cerámica
# 4     9000165                           Título Superior de Danza
# ...       ...                                                ...
# 7356  3001863  Máster Universitario en Conservación del Patri...
# 7357  4310966  Máster Universitario en Conservación del Patri...
# 7358  3001865  Máster Universitario en Conservación y Restaur...
# 7359  4310967  Máster Universitario en Conservación y Restaur...
# 7360  3002753  Máster Universitario en Construcciones e Insta...
#
#                                             Universidad  \
# 0     Centros autorizados para impartir Enseñanzas A...
# 1     Centros autorizados para impartir Enseñanzas A...
# 2     Centros autorizados para impartir Enseñanzas A...
# 3     Centros autorizados para impartir Enseñanzas A...
# 4     Centros autorizados para impartir Enseñanzas A...
# ...                                                 ...
# 7356                Universitat Politècnica de València
# 7357                Universitat Politècnica de València
# 7358                Universitat Politècnica de València
# 7359                Universitat Politècnica de València
# 7360                Universitat Politècnica de València
#
#                 Nivel académico  \
# 0            Título Equivalente
# 1            Título Equivalente
# 2            Título Equivalente
# 3            Título Equivalente
# 4            Título Equivalente
# ...                         ...
# 7356    Máster - RD 56/2005 (2)
# 7357  Máster - RD 1393/2007 (1)
# 7358    Máster - RD 56/2005 (2)
# 7359  Máster - RD 1393/2007 (1)
# 7360    Máster - RD 56/2005 (2)
#
#                                                  Estado  \
# 0                                   Publicado en B.O.E.
# 1                                   Publicado en B.O.E.
# 2                                   Publicado en B.O.E.
# 3                                   Publicado en B.O.E.
# 4                                   Publicado en B.O.E.
# ...                                                 ...
# 7356  Autorizado por Comunidad Autónoma  (TITULACIÓN...
# 7357         Publicado en B.O.E.  (TITULACIÓN RENOVADA)
# 7358  Autorizado por Comunidad Autónoma  (TITULACIÓN...
# 7359         Publicado en B.O.E.  (TITULACIÓN RENOVADA)
# 7360  Autorizado por Comunidad Autónoma  (TITULACIÓN...
#
#                                                     URL
# 0     https://www.educacion.gob.es/ruct/estudio.acti...
# 1     https://www.educacion.gob.es/ruct/estudio.acti...
# 2     https://www.educacion.gob.es/ruct/estudio.acti...
# 3     https://www.educacion.gob.es/ruct/estudio.acti...
# 4     https://www.educacion.gob.es/ruct/estudio.acti...
# ...                                                 ...
# 7356  https://www.educacion.gob.es/ruct/estudio.acti...
# 7357  https://www.educacion.gob.es/ruct/estudio.acti...
# 7358  https://www.educacion.gob.es/ruct/estudio.acti...
# 7359  https://www.educacion.gob.es/ruct/estudio.acti...
# 7360  https://www.educacion.gob.es/ruct/estudio.acti...
#
# [7361 rows x 6 columns]

# %%
df_RUCT.to_json(r'ruct.json',orient='records')
